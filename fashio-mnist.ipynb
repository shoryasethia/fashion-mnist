# %%
import tensorflow as tf
from keras import datasets, layers, models
import time
from matplotlib import pyplot as plt
import numpy as np

# %%
from subplt import *
from class_list import *
from mlp1 import *
from mlp2 import *
from mlp3 import *

# %%
(X_train, y_train),(X_test,y_test) = datasets.fashion_mnist.load_data()

# %%
print(f"Training data shape = {X_train.shape}")
print(f"Training labels shape = {y_train.shape}")
print(f"Testing data shape = {X_test.shape}")
print(f"Testing labels shape = {y_test.shape}")
# Out:
# Training data shape = (60000, 28, 28)
# Training labels shape = (60000,)
# Testing data shape = (10000, 28, 28)
# Testing labels shape = (10000,)

# %%
X_train.max()
# Out:
# 255

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
subplt(rows = 5,cols = 5, img = X_train, label = y_train)

# %%
mlp1 = mlp1((28,28))
mlp1.summary()
# Out:
# c:\Users\shory\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "MLP1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ...

# %%
mlp1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tmlp1 = time.time()
history1 = mlp1.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size = 512)
etmlp1 = time.time() - tmlp1

mlp1.save("mlp1-fashion-mnist.h5")
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6465 - loss: 1.0005 - val_accuracy: 0.8314 - val_loss: 0.4750
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8244 - loss: 0.5023 - val_accuracy: 0.8512 - val_loss: 0.4274
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8476 - loss: 0.4389 - val_accuracy: 0.8473 - val_loss: 0.4132
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8474 - loss: 0.4261 - val_accuracy: 0.8622 - val_loss: 0.3826
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8604 - loss: 0.3910 - val_accuracy: 0.8698 - val_loss: 0.3623
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8631 - loss: 0.3778 - val_accuracy: 0.8766 - val_loss: 0.3432
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8693 - loss: 0.3617 - val_accuracy: 0.8722 - val_loss: 0.3518
# Epoch 8/20
# ...

# %%
mlp2 = mlp2((28,28))
mlp2.summary()
# Out:
# Model: "MLP2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ...

# %%
mlp2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tmlp2 = time.time()
history2 = mlp2.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size = 512)
etmlp2 = time.time() - tmlp2

mlp2.save("mlp2-fashion-mnist.h5")
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.6388 - loss: 1.0048 - val_accuracy: 0.8366 - val_loss: 0.4644
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8208 - loss: 0.4928 - val_accuracy: 0.8501 - val_loss: 0.4191
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8376 - loss: 0.4448 - val_accuracy: 0.8578 - val_loss: 0.3927
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8495 - loss: 0.4096 - val_accuracy: 0.8652 - val_loss: 0.3676
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8589 - loss: 0.3785 - val_accuracy: 0.8755 - val_loss: 0.3479
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8616 - loss: 0.3684 - val_accuracy: 0.8808 - val_loss: 0.3328
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8712 - loss: 0.3505 - val_accuracy: 0.8774 - val_loss: 0.3373
# Epoch 8/20
# ...

# %%
mlp3 = mlp3((28,28))
mlp3.summary()
# Out:
# Model: "MLP3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ...

# %%
mlp3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tmlp3 = time.time()
history3 = mlp3.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size = 512)
etmlp3 = time.time() - tmlp3

mlp3.save("mlp3-fashion-mnist.h5")
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.5821 - loss: 1.1857 - val_accuracy: 0.8069 - val_loss: 0.5146
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8154 - loss: 0.5110 - val_accuracy: 0.8518 - val_loss: 0.4159
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8348 - loss: 0.4511 - val_accuracy: 0.8592 - val_loss: 0.3843
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8471 - loss: 0.4198 - val_accuracy: 0.8712 - val_loss: 0.3634
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8538 - loss: 0.3949 - val_accuracy: 0.8736 - val_loss: 0.3520
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8586 - loss: 0.3791 - val_accuracy: 0.8744 - val_loss: 0.3458
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8665 - loss: 0.3626 - val_accuracy: 0.8758 - val_loss: 0.3402
# Epoch 8/20
# ...

# %%
times = {
    1: etmlp1,
    2: etmlp2,
    3: etmlp3
}

for i in range(1, 4):
    print(f"Time taken by mlp{i} to fit = {times[i]}")
# Out:
# Time taken by mlp1 to fit = 23.13996434211731
# Time taken by mlp2 to fit = 39.594420194625854
# Time taken by mlp3 to fit = 52.22075414657593

# %%
res = []
res.append(mlp1.evaluate(X_test,y_test))
res.append(mlp2.evaluate(X_test,y_test))
res.append(mlp3.evaluate(X_test,y_test))

for i, result in enumerate(res, start=1):
    print(f"Evaluation results for mlp{i}:")
    print("Loss:", result[0])
    print("Accuracy:", result[1], "\n")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8842 - loss: 0.3215
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8824 - loss: 0.3171
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8836 - loss: 0.3169
# Evaluation results for mlp1:
# Loss: 0.32454681396484375
# Accuracy: 0.8823999762535095
#
# Evaluation results for mlp2:
# Loss: 0.32258909940719604
# Accuracy: 0.8848999738693237
#
# Evaluation results for mlp3:
# Loss: 0.3189684748649597
# Accuracy: 0.8859000205993652

# %%
from history import *

plot_all_histories([history1, history2, history3])

# %%
import cv2

# %% [markdown]
# ## MLP1 Predictions

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# set up matplotlib fig, and size it to fit 3x4 pics
nrows = 3
ncols = 8
fig = plt.gcf()
fig.set_size_inches(ncols * 3, nrows * 3)

# randomly select a few testing digits
num_predictions = nrows * ncols
test_indices = np.random.choice(np.arange(0, len(y_test)), size=(num_predictions,))
test_images = np.stack(([X_test[i] for i in test_indices]))
test_labels = np.stack(([y_test[i] for i in test_indices]))

# compute predictions
predictions = mlp1.predict(test_images)

for i in range(num_predictions):
    # select the most probable class
    prediction = np.argmax(predictions[i])

    # rescale the test image
    image = (test_images[i] * 255).astype("uint8")

    # resize the image from a 28 x 28 image to a 96 x 96 image so we can better see it
    image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_CUBIC)

    # convert grayscale image to RGB color
    image = cv2.merge([image] * 3)

    # select prediction text color
    if prediction == test_labels[i]:
        rgb_color = 'green'  # green for correct predictions
    else:
        rgb_color = 'red'  # red for wrong predictions

    # show the image and prediction
    plt.subplot(nrows, ncols, i + 1, title="label: %s" % test_labels[i])
    plt.axis('Off')  # don't show axes (or gridlines)
    plt.imshow(image)
    plt.text(0, 18, str(prediction), color=rgb_color, fontsize=30)

# show figure matrix
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Compute predictions
predictions = mlp1.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_test, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix for MLP1')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step

# %% [markdown]
# ## MLP2 predictions

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# set up matplotlib fig, and size it to fit 3x4 pics
nrows = 3
ncols = 8
fig = plt.gcf()
fig.set_size_inches(ncols * 3, nrows * 3)

# randomly select a few testing digits
num_predictions = nrows * ncols
test_indices = np.random.choice(np.arange(0, len(y_test)), size=(num_predictions,))
test_images = np.stack(([X_test[i] for i in test_indices]))
test_labels = np.stack(([y_test[i] for i in test_indices]))

# compute predictions
predictions = mlp2.predict(test_images)

for i in range(num_predictions):
    # select the most probable class
    prediction = np.argmax(predictions[i])

    # rescale the test image
    image = (test_images[i] * 255).astype("uint8")

    # resize the image from a 28 x 28 image to a 96 x 96 image so we can better see it
    image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_CUBIC)

    # convert grayscale image to RGB color
    image = cv2.merge([image] * 3)

    # select prediction text color
    if prediction == test_labels[i]:
        rgb_color = 'green'  # green for correct predictions
    else:
        rgb_color = 'red'  # red for wrong predictions

    # show the image and prediction
    plt.subplot(nrows, ncols, i + 1, title="label: %s" % test_labels[i])
    plt.axis('Off')  # don't show axes (or gridlines)
    plt.imshow(image)
    plt.text(0, 18, str(prediction), color=rgb_color, fontsize=30)

# show figure matrix
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Compute predictions
predictions = mlp2.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_test, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix for MLP2')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## MLP3 Predictions

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# set up matplotlib fig, and size it to fit 3x4 pics
nrows = 3
ncols = 8
fig = plt.gcf()
fig.set_size_inches(ncols * 3, nrows * 3)

# randomly select a few testing digits
num_predictions = nrows * ncols
test_indices = np.random.choice(np.arange(0, len(y_test)), size=(num_predictions,))
test_images = np.stack(([X_test[i] for i in test_indices]))
test_labels = np.stack(([y_test[i] for i in test_indices]))

# compute predictions
predictions = mlp3.predict(test_images)

for i in range(num_predictions):
    # select the most probable class
    prediction = np.argmax(predictions[i])

    # rescale the test image
    image = (test_images[i] * 255).astype("uint8")

    # resize the image from a 28 x 28 image to a 96 x 96 image so we can better see it
    image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_CUBIC)

    # convert grayscale image to RGB color
    image = cv2.merge([image] * 3)

    # select prediction text color
    if prediction == test_labels[i]:
        rgb_color = 'green'  # green for correct predictions
    else:
        rgb_color = 'red'  # red for wrong predictions

    # show the image and prediction
    plt.subplot(nrows, ncols, i + 1, title="label: %s" % test_labels[i])
    plt.axis('Off')  # don't show axes (or gridlines)
    plt.imshow(image)
    plt.text(0, 18, str(prediction), color=rgb_color, fontsize=30)

# show figure matrix
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Compute predictions
predictions = mlp3.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_test, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix for MLP3')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### All three models (mlp1, mlp2, mlp3) are bit **in-accurate** in distinguishing between **shirt/t-shirt/pullover/coat**
